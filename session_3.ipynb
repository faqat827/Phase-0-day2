# %%
Herose=("Batman","Ironman","Hulk","Superman")
heroes_list=list(Herose)
heroes_list[0]="Isho Speed"
print(heroes_list)
# Out:
# ['Isho Speed', 'Ironman', 'Hulk', 'Superman']

# %%
Herose[0]="Isho Speed"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 Herose[0]="Isho Speed"
#
# TypeError: 'tuple' object does not support item assignment

# %%
print(type(Herose))
print(type(heroes_list))
# Out:
# <class 'tuple'>
# <class 'list'>

# %%
new_list=[]
for i in Herose:
    new_list.append(i)
    print(new_list)
# Out:
# ['Batman']
# ['Batman', 'Ironman']
# ['Batman', 'Ironman', 'Hulk']
# ['Batman', 'Ironman', 'Hulk', 'Superman']

# %%
# Out:
# Name: faqat
# Chemistry score: 90
# Biology score: 90
# Maths score: 90
# Your marks are: 90 and you got A grade in Chemistry
# Your marks are: 90 and you got A grade in Biology
# Your marks are: 90 and you got A grade in maths

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 input_()
# ----> 2 print_()
#       3 grades()
#
# Cell In[6], line 15, in print_()
#      14 def print_():
# ---> 15     print("Student data: ", data)
#
# NameError: name 'data' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 main()
#
# NameError: name 'main' is not defined
